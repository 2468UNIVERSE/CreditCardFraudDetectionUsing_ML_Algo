# %% [markdown]
# Importing pandas library for manipulation like uploading, cleaning, and removing null vaues from the dataset

# %%
import pandas as pd

# %% [markdown]
# 1- reading the csv file (dataset)

# %%
df = pd.read_csv('creditcard.csv')

# %% [markdown]
# 2- visualising the general detils of dataset
#   head() - display the first 5 rows of data by default
#   tail() - display the last 5 rows data by default
#   shape -  display the size of the dataset

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# To see all the columns

# %%
pd.options.display.max_columns = None

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %% [markdown]
# Printing number of rows and columns individually
# 0- represent rows
# 1- represent columns

# %%
print('Number of columns: {}'.format(df.shape[1]))
print('Number of rows: {}'.format(df.shape[0]))
# Out:
# Number of columns: 31
# Number of rows: 284807

# %% [markdown]
# To display the info of the dataset to see if it contain any null value or not

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Standardrised the amount column

# %%
sc = StandardScaler()
df['Amount'] = sc.fit_transform(pd.DataFrame(df['Amount']))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %% [markdown]
# Dropping the time column

# %%
df = df.drop(['Time'], axis = 1)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %% [markdown]
# Checkin for duplicate date in the dataset

# %%
df.duplicated().any()
# Out:
# True

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (275663, 30)

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Class', palette='Set2')
plt.title('Class Distribution (Fraud vs Non-Fraud)', fontsize=14)
plt.xlabel('Class (0 = Non-Fraud, 1 = Fraud)', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks([0, 1], ['Non-Fraud', 'Fraud'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3116\4152898398.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Class', palette='Set2')

# %% [markdown]
# Dividing the data set

# %%
X = df.drop('Class', axis = 1)
Y = df['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# model formation on unbalanced data to see the result

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name, clf in classifier.items():
    print(f"\n======={name}=======")
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    
    # accuracy = accuracy_score(Y_test, Y_pred)
    
    print(f"\n Accuracy: {accuracy_score(Y_test, Y_pred)}")
    print(f"\n Precision: {precision_score(Y_test, Y_pred)}")
    print(f"\n Recall: {recall_score(Y_test, Y_pred)}")
    print(f"\n F1 Score: {f1_score(Y_test, Y_pred)}")
# Out:
# =======Logistic Regression=======
#
#  Accuracy: 0.9368421052631579
#
#  Precision: 0.96875
#
#  Recall: 0.9117647058823529
#
#  F1 Score: 0.9393939393939394
#
# =======Decision Tree Classifier=======
#
#  Accuracy: 0.9052631578947369
#
#  Precision: 0.92
#
#  Recall: 0.9019607843137255
#
#  F1 Score: 0.9108910891089109

# %% [markdown]
# Handling the unbalanced data

# %% [markdown]
# lets first work with undersampling

# %%
normal = df[df['Class'] == 0]
fraud = df[df['Class'] == 1]
print(normal.shape)
print(fraud.shape)
# Out:
# (275190, 30)
# (473, 30)

# %%
normal_sample = normal.sample(n = 473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_df = pd.concat([normal_sample,fraud],ignore_index = True)

# %%
new_df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  0.968988 -1.452021  0.723129 -0.372233 -1.312076  0.528160 -0.930387
# 1  0.896858 -1.017576  0.542084  0.606867 -0.930532  0.588686 -0.592229
# 2  1.706975 -1.831663 -0.266092 -1.663596 -1.630517 -0.036870 -1.182239
# 3  1.764057  0.137895  0.172484  3.888009 -0.314876  0.257851 -0.409219
# 4  1.294470 -1.303826  0.746746 -1.177904 -1.999615 -1.082874 -0.963086
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.156316  0.093526  0.239347 -1.016076 -0.142271  0.505439 -0.945833
# 1  0.210508 -0.831398  0.799381  0.702692  0.611117  0.073460  0.077886
# 2  0.146524  3.787572 -1.598236 -1.901144  0.716251 -0.342414 -0.720576
# 3  0.077856 -0.386308  1.370267 -1.260745 -0.131806  0.298555 -0.211538
# 4 -0.206245 -1.727903  1.378089 -0.184265 -0.889236  0.191023 -0.279732
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
new_df.shape
# Out:
# (946, 30)

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
X = new_df.drop('Class', axis = 1)
Y = new_df['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name, clf in classifier.items():
    print(f"\n======={name}=======")
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    
    # accuracy = accuracy_score(Y_test, Y_pred)
    
    print(f"\n Accuracy: {accuracy_score(Y_test, Y_pred)}")
    print(f"\n Precision: {precision_score(Y_test, Y_pred)}")
    print(f"\n Recall: {recall_score(Y_test, Y_pred)}")
    print(f"\n F1 Score: {f1_score(Y_test, Y_pred)}")
# Out:
# =======Logistic Regression=======
#
#  Accuracy: 0.9421052631578948
#
#  Precision: 0.9789473684210527
#
#  Recall: 0.9117647058823529
#
#  F1 Score: 0.9441624365482234
#
# =======Decision Tree Classifier=======
#
#  Accuracy: 0.9
#
#  Precision: 0.9191919191919192
#
#  Recall: 0.8921568627450981
#
#  F1 Score: 0.9054726368159204

# %% [markdown]
# we have to perform oversampling using SMOTE

# %%
X = df.drop('Class', axis = 1)
Y = df['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
Y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res, Y_res = SMOTE().fit_resample(X,Y)

# %%
Y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_res, Y_res, test_size = 0.2, random_state = 42, stratify= Y_res)

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier()
}

for name, clf in classifier.items():
    print(f"\n======={name}=======")
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    
    # accuracy = accuracy_score(Y_test, Y_pred)
    
    print(f"\n Accuracy: {accuracy_score(Y_test, Y_pred)}")
    print(f"\n Precision: {precision_score(Y_test, Y_pred)}")
    print(f"\n Recall: {recall_score(Y_test, Y_pred)}")
    print(f"\n F1 Score: {f1_score(Y_test, Y_pred)}")
# Out:
# =======Logistic Regression=======
#
#  Accuracy: 0.9454104436934482
#
#  Precision: 0.9743609589968846
#
#  Recall: 0.9148951633416912
#
#  F1 Score: 0.9436921952453686
#
# =======Decision Tree Classifier=======
#
#  Accuracy: 0.9982194120425888
#
#  Precision: 0.9974601792387794
#
#  Recall: 0.9989825211671935
#
#  F1 Score: 0.9982207697893972

# %% [markdown]
# decision tree is showing more good result

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_res, Y_res)
# Out:
# DecisionTreeClassifier()

# %%
import joblib

# %%
joblib.dump(dtc, "credit_card_model.pkl")
# Out:
# ['credit_card_model.pkl']

# %%
model = joblib.load("credit_card_model.pkl")

# %%
pred = model.predict([[-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
pred[0]
# Out:
# 0

# %%
if pred[0] == 0:
    print('Normal Transaction')
else:
    print('Fraud Transcation')
# Out:
# Normal Transaction
